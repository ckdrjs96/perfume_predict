# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os,shutil

# %%
original_dataset_dir = '/content/drive/My Drive/Colab Notebooks/yjproject/perfume'

base_dir='/content/drive/My Drive/Colab Notebooks/yjproject/perfume_small'
os.mkdir(base_dir)

# %%
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# %%
train_fp_dir = os.path.join(train_dir, 'fp')
os.mkdir(train_fp_dir)

train_jv_dir = os.path.join(train_dir, 'jv')
os.mkdir(train_jv_dir)

train_pr_dir = os.path.join(train_dir, 'pr')
os.mkdir(train_pr_dir)

# %%
test_fp_dir = os.path.join(test_dir, 'fp')
os.mkdir(test_fp_dir)

test_jv_dir = os.path.join(test_dir, 'jv')
os.mkdir(test_jv_dir)

test_pr_dir = os.path.join(test_dir, 'pr')
os.mkdir(test_pr_dir)
